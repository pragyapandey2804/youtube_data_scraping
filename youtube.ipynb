# %% [markdown]
# !pip install google-api-python-client pandas

# %%
import os
import pandas as pd
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api._errors import TranscriptsDisabled, NoTranscriptFound

# API setup
API_KEY = "YOUR_API_KEY"  # Replace with your YouTube API key
youtube = build('youtube', 'v3', developerKey=API_KEY)

def get_top_videos(genre, max_results=500):
    """Fetch the top videos for a specific genre."""
    video_ids = []
    next_page_token = None

    while len(video_ids) < max_results:
        search_response = youtube.search().list(
            part='id,snippet',
            q=genre,
            type='video',
            maxResults=min(50, max_results - len(video_ids)),
            pageToken=next_page_token
        ).execute()

        for item in search_response['items']:
            video_ids.append(item['id']['videoId'])
        
        next_page_token = search_response.get('nextPageToken')
        if not next_page_token:
            break

    return video_ids

def get_video_details(video_ids, genre):
    """Fetch video details for a list of video IDs."""
    video_details = []
    captions_folder = f"captions_{genre}"  # Dynamic folder name based on genre
    os.makedirs(captions_folder, exist_ok=True)  # Create captions folder dynamically in the current directory

    for i in range(0, len(video_ids), 50):
        response = youtube.videos().list(
            part='snippet,contentDetails,statistics,topicDetails',
            id=','.join(video_ids[i:i+50])
        ).execute()

        for video in response['items']:
            video_id = video['id']
            caption_file_link = fetch_and_save_english_captions(video_id, captions_folder)

            details = {
                'Video URL': f"https://www.youtube.com/watch?v={video_id}",
                'Title': video['snippet']['title'],
                'Description': video['snippet']['description'],
                'Channel Title': video['snippet']['channelTitle'],
                'Keyword Tags': ', '.join(video['snippet'].get('tags', [])),
                'Category': video['snippet'].get('categoryId', 'N/A'),
                'Topics': ', '.join(video.get('topicDetails', {}).get('topicCategories', [])),
                'Published At': video['snippet']['publishedAt'],
                'Duration': video['contentDetails']['duration'],
                'View Count': video['statistics'].get('viewCount', '0'),
                'Comment Count': video['statistics'].get('commentCount', '0'),
                'Captions Available': 'true' if video['contentDetails'].get('caption') == 'true' else 'false',
                'Caption File': caption_file_link or "No English captions available",
                'Location': video.get('recordingDetails', {}).get('locationDescription', 'N/A')
            }
            video_details.append(details)
    
    return video_details

def fetch_and_save_english_captions(video_id, captions_folder):
    """Fetch only English captions for a video and save them to a text file."""
    try:
        # Fetch all available transcripts
        transcripts = YouTubeTranscriptApi.list_transcripts(video_id)

        # Check for English captions
        english_transcript = transcripts.find_transcript(['en'])

        # Fetch the transcript text
        transcript = english_transcript.fetch()
        captions = "\n".join([entry['text'] for entry in transcript])

        # Save captions to a file in the folder for the genre
        caption_file_path = os.path.join(captions_folder, f"{video_id}_captions.txt")
        with open(caption_file_path, 'w', encoding='utf-8') as file:
            file.write(captions)
        
        return os.path.join(captions_folder, f"{video_id}_captions.txt")  # Return the relative path

    except (TranscriptsDisabled, NoTranscriptFound):
        print(f"Captions not available for video {video_id}.")
        return None
    except Exception as e:
        print(f"Error fetching captions for video {video_id}: {e}")
        return None

def save_to_csv(data, filename):
    """Save video details to a CSV file."""
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)
    print(f"Data saved to {filename}")

if __name__ == "__main__":
    # Input dynamic genre
    genre = input("Enter the genre (e.g., 'coding', 'deep learning', 'music', etc.): ").strip()
    if not genre:
        print("Genre is required. Exiting.")
        exit()

    print(f"Fetching videos for the genre: {genre}")

    # Step 1: Get top videos
    print("Fetching video IDs...")
    video_ids = get_top_videos(genre)

    # Step 2: Get video details and captions
    print("Fetching video details and captions...")
    video_details = get_video_details(video_ids, genre)

    # Step 3: Save to CSV
    filename = f"{genre.replace(' ', '_')}_videos.csv"
    print(f"Saving data to {filename}...")
    save_to_csv(video_details, filename)
# Out:
# Enter the genre (e.g., 'coding', 'deep learning', 'music', etc.):  kids
# Fetching videos for the genre: kids
# Fetching video IDs...
# Fetching video details and captions...
# Captions not available for video -_5dLLUbXNc.
# Captions not available for video jz8g1ONWIEU.
# Captions not available for video _bEeW9lZpiI.
# Captions not available for video gNn_UJBM6i0.
# Captions not available for video fGSypHaiYhI.
# Captions not available for video t4j8JWKGjVY.
# Captions not available for video C5RfStYM5b8.
# Captions not available for video euqfS-67j68.
# Captions not available for video cvL_KDtZ1cY.
# Captions not available for video AwP8EldLeA4.
# Captions not available for video _iQ6pl9-iOk.
# Captions not available for video vGz7dcKoxLA.
# Captions not available for video kFP2Crc5P3s.
# Captions not available for video MgZ1QYpX9zM.
# Captions not available for video aMGQtiQUdkA.
# Captions not available for video yASoTC2LbcM.
# Captions not available for video WRVsOCh907o.
# Captions not available for video hxOApe1P9dM.
# Captions not available for video DZ9mjmg3nG8.
# Captions not available for video TLjifvCnOfk.
# Captions not available for video H86i72hNAUk.
# Captions not available for video _iQ6pl9-iOk.
# Captions not available for video eFmQRODHD_Y.
# Captions not available for video hxOApe1P9dM.
# Captions not available for video y8kneKeNyCI.
# Captions not available for video poWI4n59mwc.
# Captions not available for video 4TpW-Qfjd-0.
# Captions not available for video 4Mymm0H-9s0.
# Captions not available for video VV5oVYVGfNc.
# Captions not available for video edyh71THv_8.
# Captions not available for video rWB6ZKm9t6A.
# Captions not available for video aG2D8AT4Juw.
# Captions not available for video _UR-l3QI2nE.
# Captions not available for video EN1SJT76JoY.
# Captions not available for video edyh71THv_8.
# Captions not available for video DZ9mjmg3nG8.
# Captions not available for video HkW4v0JPOoU.
# Captions not available for video QW3rt5yyhuY.
# Captions not available for video EN1SJT76JoY.
# Captions not available for video w8sB13HRwXc.
# Captions not available for video ubspZnidcak.
# Captions not available for video OQ4yWEGQsX4.
# Captions not available for video A2DMRR95Hgk.
# Captions not available for video w1B2VXWHiA0.
# Captions not available for video zpqmF24SjaU.
# Captions not available for video xX3rX3-fmRY.
# Captions not available for video 9DY2mpHNUbk.
# Captions not available for video eFmQRODHD_Y.
# Captions not available for video g6CVApMxmqg.
# Captions not available for video p83zm9CHcSo.
# Captions not available for video klFFcrl4V_I.
# Captions not available for video QW3rt5yyhuY.
# Captions not available for video YovYo5R1Bm4.
# Captions not available for video skrRkJvDgjE.
# Captions not available for video 3BZUnyj6dl8.
# Captions not available for video Nn1Zs_ijOZA.
# Captions not available for video eTuKMyi1bS4.
# Captions not available for video pSHhu5Fq2ls.
# Captions not available for video DZ9mjmg3nG8.
# Captions not available for video HkW4v0JPOoU.
# Captions not available for video 3BZUnyj6dl8.
# Captions not available for video IoqK1zGwsH4.
# Captions not available for video LhM-YlcBKw0.
# Captions not available for video klFFcrl4V_I.
# Captions not available for video 20DEifxV5Fg.
# Captions not available for video 9cS3_RTaZyE.
# Captions not available for video n_MXKfhriYE.
# Captions not available for video O5lruCPRcts.
# Captions not available for video Nn1Zs_ijOZA.
# Captions not available for video QW3rt5yyhuY.
# Captions not available for video YCXEniRfsFo.
# Captions not available for video CW3AUmJ_Dpc.
# Captions not available for video 1DXQgrH8hOc.
# Captions not available for video tbxVSEBdnrQ.
# Captions not available for video CgKQltqaDZo.
# Captions not available for video LY1oAC1nUaw.
# Captions not available for video 0_EFygChhUU.
# Captions not available for video LENiFwUOQQg.
# Captions not available for video 2AYu4TLEDno.
# Captions not available for video LOFfkFBkLdk.
# Captions not available for video ZqWmztkLm-U.
# Captions not available for video mBXcysZtEN0.
# Captions not available for video zrRjJllUYpw.
# Captions not available for video DZ9mjmg3nG8.
# Captions not available for video jgpRCKUc0aw.
# Captions not available for video kGQIe3zr4F8.
# Captions not available for video 3B6YcMb3iGY.
# Captions not available for video _wFzgFmIMUs.
# Captions not available for video prZPg5EfFws.
# Captions not available for video UcbjuTFt4QU.
# Captions not available for video NSdDtkTEnsY.
# Captions not available for video rFuoNqrTC50.
# Captions not available for video 4wfZT74dFEw.
# Captions not available for video qBU29cM0JEY.
# Captions not available for video prZPg5EfFws.
# Captions not available for video 3B6YcMb3iGY.
# Captions not available for video _wFzgFmIMUs.
# Captions not available for video bWiHbHJB17w.
# Captions not available for video UcbjuTFt4QU.
# Captions not available for video NSdDtkTEnsY.
# Captions not available for video 4wfZT74dFEw.
# Captions not available for video w1Z_aQIl40c.
# Captions not available for video UvYpyl3N2xw.
# Captions not available for video SOjdQxE1dp0.
# Captions not available for video 8B-z0cxrus4.
# Captions not available for video dFq2ZZvjFN8.
# Captions not available for video LDDHpxpkBEQ.
# Captions not available for video UgopncfO3-A.
# Captions not available for video vNC1W2m4Uug.
# Captions not available for video fYzvFXcRY4M.
# Captions not available for video a89xt_RM2Qo.
# Captions not available for video MGEelVrBDWc.
# Captions not available for video QUH_UIqONao.
# Captions not available for video Ia6bmaZnl9Q.
# Captions not available for video DHfmNCD1PxM.
# Captions not available for video 7_3ADDvMZjI.
# Captions not available for video bUU6PLcVKyU.
# Captions not available for video mHEUZ7lgA1s.
# Captions not available for video TSvdwQ_0-6Q.
# Captions not available for video TSvdwQ_0-6Q.
# Captions not available for video jDyWnBNJ8OM.
# Captions not available for video j9TuDFiZXgc.
# Captions not available for video 4YxgqXofEkE.
# Captions not available for video h9-Kh3q_HKs.
# Captions not available for video SIj3_293ZYY.
# Captions not available for video M-CBCE4ugmE.
# Captions not available for video 8kGoXJLf4s4.
# Captions not available for video n7_gT_hHdDQ.
# Captions not available for video 4gtYpsX-HsQ.
# Captions not available for video 6liZbg_pPYg.
# Captions not available for video Cp-_v3isn8w.
# Captions not available for video kaB1fYZp3GA.
# Captions not available for video 6liZbg_pPYg.
# Captions not available for video iNUDOQPDS3M.
# Captions not available for video -uQi0vJK9lk.
# Captions not available for video 7WaOvNHY6zE.
# Captions not available for video jgpRCKUc0aw.
# Captions not available for video LENiFwUOQQg.
# Captions not available for video L0Jd-AbaCzI.
# Captions not available for video 4YxgqXofEkE.
# Captions not available for video D12h-XfBNCQ.
# Captions not available for video gx73-yJ7Wc0.
# Captions not available for video ZqWmztkLm-U.
# Captions not available for video dSdvgmhShu8.
# Captions not available for video KXe22y1GEXk.
# Captions not available for video vQPissJbGCo.
# Captions not available for video a6GeX9n2erY.
# Captions not available for video ENriLcJANVg.
# Captions not available for video rZtYtydM2Rs.
# Captions not available for video z6MMB0tyhp8.
# Captions not available for video armSdDi8i9Q.
# Saving data to kids_videos.csv...
# Data saved to kids_videos.csv
